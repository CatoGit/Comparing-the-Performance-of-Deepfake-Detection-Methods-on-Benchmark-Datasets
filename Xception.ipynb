# %% [markdown]
# <a href="https://colab.research.google.com/github/CatoGit/Comparing-the-Performance-of-Deepfake-Detection-Methods-on-Benchmark-Datasets/blob/master/Xception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reimplementation of Francois Chollet's Xception: Deep Learning with Depthwise Separable Convolutions. (https://arxiv.org/pdf/1610.02357.pdf)
#
# Reimplementation by: Christopher Otto

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, MaxPool2D, BatchNormalization
from tensorflow.keras.layers import Conv2D, SeparableConv2D, ReLU, Add
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras import Model

# %%
print(tf.__version__)
# Out:
# 2.2.0-rc2

# %%
def module1(input, filters, kernel_size, strides):
    """Xception Module 1/14 - Entry Module"""
    x = Conv2D(filters=filters, 
               kernel_size=kernel_size, 
               strides=strides,
               use_bias=False)(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv2D(filters=64, 
               kernel_size=(3,3), 
               strides=(1,1),
               use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x


def module2(tensor, 
            filters, 
            kernel_size, 
            strides,
            padding,
            bias):
    """Xception Module 2/14"""
    x = SeparableConv2D(filters=filters, 
                        kernel_size=kernel_size, 
                        strides=strides,
                        padding=padding,
                        use_bias=bias)(tensor)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = SeparableConv2D(filters=128,
                        kernel_size=(3,3),
                        strides=(1,1),                      
                        padding='same',
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(3,3), strides=(2,2), padding='same')(x)
    #calculate resiudal
    residual = linear_residual_connection(tensor,
                                   filters=128,
                                   kernel_size=(1,1),
                                   strides=(2,2),
                                   padding='same',
                                   bias = False)
    
    #perform addition of residual and module output
    x = Add()([x, residual])
    return x

def module3(tensor, 
            filters, 
            kernel_size, 
            strides,
            padding,
            depth_multiplier,
            bias):
    """Xception Module 3/14"""
    x = ReLU()(tensor)
    x = SeparableConv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides,
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = SeparableConv2D(filters=256,
                        kernel_size=(3,3),
                        strides=(1,1),
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(3,3), strides=(2,2), padding='same')(x)
    #calculate resiudal
    residual = linear_residual_connection(tensor,
                                   filters=256,
                                   kernel_size=(1,1),
                                   strides=(2,2),
                                   padding='same',
                                   bias = False)

    #perform addition of residual and module output
    x = Add()([x, residual])
    return x


def module4(tensor, 
            filters, 
            kernel_size, 
            strides,
            padding,
            depth_multiplier,
            bias):
    """Xception Module 4/14"""
    x = ReLU()(tensor)
    x = SeparableConv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides,
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = SeparableConv2D(filters=728,
                        kernel_size=(3,3),
                        strides=(1,1),
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(3,3), strides=(2,2), padding='same')(x)

    #calculate resiudal
    residual = linear_residual_connection(tensor,
                                   filters=728,
                                   kernel_size=(1,1),
                                   strides=(2,2),
                                   padding='same',
                                   bias = False)

    #perform addition of residual and module output
    x = Add()([x, residual])
    return x

def module5_to_12(tensor,
            residual, 
            filters, 
            kernel_size, 
            strides,
            padding,
            depth_multiplier,
            bias):
    """Xception Module 5 to 12 (all the same)"""
    x = ReLU()(tensor)
    x = SeparableConv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides,
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = SeparableConv2D(filters=728,
                        kernel_size=(3,3),
                        strides=(1,1),
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = SeparableConv2D(filters=728,
                        kernel_size=(3,3),
                        strides=(1,1),
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    

    #no convolution this time
    residual = residual

    #perform addition of residual and module output
    x = Add()([x, residual])
    return x


def module13(tensor, 
            filters, 
            kernel_size, 
            strides,
            padding,
            depth_multiplier,
            bias):
    """Xception Module 13/14"""
    x = ReLU()(tensor)
    x = SeparableConv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides,
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = SeparableConv2D(filters=1024,
                        kernel_size=(3,3),
                        strides=(1,1),
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(3,3), strides=(2,2), padding='same')(x)

    #calculate resiudal
    residual = linear_residual_connection(tensor,
                                   filters=1024,
                                   kernel_size=(1,1),
                                   strides=(2,2),
                                   padding='same',
                                   bias = False)

    #perform addition of residual and module output
    x = Add()([x, residual])
    return x

    
def module14(tensor, 
              filters, 
              kernel_size, 
              strides,
              padding,
              depth_multiplier,
              bias):
    """Xception Module 14/14 Exit Module"""
    x = SeparableConv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides,
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(tensor)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = SeparableConv2D(filters=2048,
                        kernel_size=(3,3),
                        strides=(1,1),
                        padding='same',
                        depth_multiplier=1,
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = GlobalAveragePooling2D()(x)
    return x 

def model_fcs(output, classes):
    """Fully connected layers of the model."""
    if classes == 2 or classes == 1:
        print("Binary classification.")
        if classes == 2:
            classes = 1
        x = Dense(classes, activation='sigmoid')(output)
    else:
        print(f"{classes} class classification.")
        x = Dense(classes, activation = 'softmax')(output)
    return x


def linear_residual_connection(tensor,
                               filters, 
                               kernel_size, 
                               strides, 
                               padding,
                               bias):
    """Xception residual connection"""
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=strides,
               padding=padding,
               use_bias=bias)(tensor)
    x = BatchNormalization()(x)
    return x

# %%
def Xception(input_shape=(299,299,3), classes=1):
    """Reimplementation of Francois Chollet's Xception: Deep Learning with Depthwise Separable Convolutions."""
    input = Input(shape=input_shape)
    x = module1(input, filters=32,kernel_size=(3,3), strides=(2,2))
    x = module2(x,
                filters=128,
                kernel_size=(3,3),
                strides=(1,1),
                padding='same',
                bias=False)
    x = module3(x,
                filters=256,
                kernel_size=(3,3),
                strides=(1,1),
                padding='same',
                depth_multiplier=1,
                bias=False)
    x = module4(x,
              filters=728,
              kernel_size=(3,3),
              strides=(1,1),
              padding='same',
              depth_multiplier=1,
              bias=False)
    
    
    for _ in range(8):
        residual = x

        x = module5_to_12(x,
                          residual,
                          filters=728,
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='same',
                          depth_multiplier=1,
                          bias=False)
    
    x = module13(x,
                 filters=728,
                 kernel_size=(3,3),
                 strides=(1,1),
                 padding='same',
                 depth_multiplier=1,
                 bias=False)
    x = module14(x,
                filters=1536,
                kernel_size=(3,3),
                strides=(1,1),
                padding='same',
                depth_multiplier=1,
                bias=False)
    
    return Model(input,x)

# %%
#utilize pretrained imagenet weights from keras
from keras.utils.data_utils import get_file
image_net_weights_from = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5'
weights = get_file("xception_weights_tf_dim_ordering_tf_kernels_notop.h5",
                   image_net_weights_from,
                   cache_subdir='models',
                   file_hash='b0042744bf5b25fce3cb969f33bebb97')

# %%
model = Xception((299,299,3), 1)
#load imagenet pretrained weights from https://github.com/keras-team/keras-applications/blob/master/keras_applications/xception.py
model.load_weights(weights)

# %%
x = model.layers[-1].output
# add fully connected top of the xception model and 
# specifiy num of output classes
x = model_fcs(x, 1)
model = Model(model.input,x)
# Out:
# Binary classification.

# %%
model.summary()
# Out:
# Model: "model_24"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 149, 149, 32) 864         input_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_600 (BatchN (None, 149, 149, 32) 128         conv2d_90[0][0]
# __________________________________________________________________________________________________
# re_lu_525 (ReLU)                (None, 149, 149, 32) 0           batch_normalization_600[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 147, 147, 64) 18432       re_lu_525[0][0]
# __________________________________________________________________________________________________
# batch_normalization_601 (BatchN (None, 147, 147, 64) 256         conv2d_91[0][0]
# __________________________________________________________________________________________________
# re_lu_526 (ReLU)                (None, 147, 147, 64) 0           batch_normalization_601[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_510 (Separable (None, 147, 147, 128 8768        re_lu_526[0][0]
# __________________________________________________________________________________________________
# batch_normalization_602 (BatchN (None, 147, 147, 128 512         separable_conv2d_510[0][0]
# __________________________________________________________________________________________________
# re_lu_527 (ReLU)                (None, 147, 147, 128 0           batch_normalization_602[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_511 (Separable (None, 147, 147, 128 17536       re_lu_527[0][0]
# __________________________________________________________________________________________________
# batch_normalization_603 (BatchN (None, 147, 147, 128 512         separable_conv2d_511[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 74, 74, 128)  8192        re_lu_526[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_60 (MaxPooling2D) (None, 74, 74, 128)  0           batch_normalization_603[0][0]
# __________________________________________________________________________________________________
# batch_normalization_604 (BatchN (None, 74, 74, 128)  512         conv2d_92[0][0]
# __________________________________________________________________________________________________
# add_180 (Add)                   (None, 74, 74, 128)  0           max_pooling2d_60[0][0]
#                                                                  batch_normalization_604[0][0]
# __________________________________________________________________________________________________
# re_lu_528 (ReLU)                (None, 74, 74, 128)  0           add_180[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_512 (Separable (None, 74, 74, 256)  33920       re_lu_528[0][0]
# __________________________________________________________________________________________________
# batch_normalization_605 (BatchN (None, 74, 74, 256)  1024        separable_conv2d_512[0][0]
# __________________________________________________________________________________________________
# re_lu_529 (ReLU)                (None, 74, 74, 256)  0           batch_normalization_605[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_513 (Separable (None, 74, 74, 256)  67840       re_lu_529[0][0]
# __________________________________________________________________________________________________
# batch_normalization_606 (BatchN (None, 74, 74, 256)  1024        separable_conv2d_513[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 37, 37, 256)  32768       add_180[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_61 (MaxPooling2D) (None, 37, 37, 256)  0           batch_normalization_606[0][0]
# __________________________________________________________________________________________________
# batch_normalization_607 (BatchN (None, 37, 37, 256)  1024        conv2d_93[0][0]
# __________________________________________________________________________________________________
# add_181 (Add)                   (None, 37, 37, 256)  0           max_pooling2d_61[0][0]
#                                                                  batch_normalization_607[0][0]
# __________________________________________________________________________________________________
# re_lu_530 (ReLU)                (None, 37, 37, 256)  0           add_181[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_514 (Separable (None, 37, 37, 728)  188672      re_lu_530[0][0]
# __________________________________________________________________________________________________
# batch_normalization_608 (BatchN (None, 37, 37, 728)  2912        separable_conv2d_514[0][0]
# __________________________________________________________________________________________________
# re_lu_531 (ReLU)                (None, 37, 37, 728)  0           batch_normalization_608[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_515 (Separable (None, 37, 37, 728)  536536      re_lu_531[0][0]
# __________________________________________________________________________________________________
# batch_normalization_609 (BatchN (None, 37, 37, 728)  2912        separable_conv2d_515[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 19, 19, 728)  186368      add_181[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_62 (MaxPooling2D) (None, 19, 19, 728)  0           batch_normalization_609[0][0]
# __________________________________________________________________________________________________
# batch_normalization_610 (BatchN (None, 19, 19, 728)  2912        conv2d_94[0][0]
# __________________________________________________________________________________________________
# add_182 (Add)                   (None, 19, 19, 728)  0           max_pooling2d_62[0][0]
#                                                                  batch_normalization_610[0][0]
# __________________________________________________________________________________________________
# re_lu_532 (ReLU)                (None, 19, 19, 728)  0           add_182[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_516 (Separable (None, 19, 19, 728)  536536      re_lu_532[0][0]
# __________________________________________________________________________________________________
# batch_normalization_611 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_516[0][0]
# __________________________________________________________________________________________________
# re_lu_533 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_611[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_517 (Separable (None, 19, 19, 728)  536536      re_lu_533[0][0]
# __________________________________________________________________________________________________
# batch_normalization_612 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_517[0][0]
# __________________________________________________________________________________________________
# re_lu_534 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_612[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_518 (Separable (None, 19, 19, 728)  536536      re_lu_534[0][0]
# __________________________________________________________________________________________________
# batch_normalization_613 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_518[0][0]
# __________________________________________________________________________________________________
# add_183 (Add)                   (None, 19, 19, 728)  0           batch_normalization_613[0][0]
#                                                                  add_182[0][0]
# __________________________________________________________________________________________________
# re_lu_535 (ReLU)                (None, 19, 19, 728)  0           add_183[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_519 (Separable (None, 19, 19, 728)  536536      re_lu_535[0][0]
# __________________________________________________________________________________________________
# batch_normalization_614 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_519[0][0]
# __________________________________________________________________________________________________
# re_lu_536 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_614[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_520 (Separable (None, 19, 19, 728)  536536      re_lu_536[0][0]
# __________________________________________________________________________________________________
# batch_normalization_615 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_520[0][0]
# __________________________________________________________________________________________________
# re_lu_537 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_615[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_521 (Separable (None, 19, 19, 728)  536536      re_lu_537[0][0]
# __________________________________________________________________________________________________
# batch_normalization_616 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_521[0][0]
# __________________________________________________________________________________________________
# add_184 (Add)                   (None, 19, 19, 728)  0           batch_normalization_616[0][0]
#                                                                  add_183[0][0]
# __________________________________________________________________________________________________
# re_lu_538 (ReLU)                (None, 19, 19, 728)  0           add_184[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_522 (Separable (None, 19, 19, 728)  536536      re_lu_538[0][0]
# __________________________________________________________________________________________________
# batch_normalization_617 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_522[0][0]
# __________________________________________________________________________________________________
# re_lu_539 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_617[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_523 (Separable (None, 19, 19, 728)  536536      re_lu_539[0][0]
# __________________________________________________________________________________________________
# batch_normalization_618 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_523[0][0]
# __________________________________________________________________________________________________
# re_lu_540 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_618[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_524 (Separable (None, 19, 19, 728)  536536      re_lu_540[0][0]
# __________________________________________________________________________________________________
# batch_normalization_619 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_524[0][0]
# __________________________________________________________________________________________________
# add_185 (Add)                   (None, 19, 19, 728)  0           batch_normalization_619[0][0]
#                                                                  add_184[0][0]
# __________________________________________________________________________________________________
# re_lu_541 (ReLU)                (None, 19, 19, 728)  0           add_185[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_525 (Separable (None, 19, 19, 728)  536536      re_lu_541[0][0]
# __________________________________________________________________________________________________
# batch_normalization_620 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_525[0][0]
# __________________________________________________________________________________________________
# re_lu_542 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_620[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_526 (Separable (None, 19, 19, 728)  536536      re_lu_542[0][0]
# __________________________________________________________________________________________________
# batch_normalization_621 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_526[0][0]
# __________________________________________________________________________________________________
# re_lu_543 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_621[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_527 (Separable (None, 19, 19, 728)  536536      re_lu_543[0][0]
# __________________________________________________________________________________________________
# batch_normalization_622 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_527[0][0]
# __________________________________________________________________________________________________
# add_186 (Add)                   (None, 19, 19, 728)  0           batch_normalization_622[0][0]
#                                                                  add_185[0][0]
# __________________________________________________________________________________________________
# re_lu_544 (ReLU)                (None, 19, 19, 728)  0           add_186[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_528 (Separable (None, 19, 19, 728)  536536      re_lu_544[0][0]
# __________________________________________________________________________________________________
# batch_normalization_623 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_528[0][0]
# __________________________________________________________________________________________________
# re_lu_545 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_623[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_529 (Separable (None, 19, 19, 728)  536536      re_lu_545[0][0]
# __________________________________________________________________________________________________
# batch_normalization_624 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_529[0][0]
# __________________________________________________________________________________________________
# re_lu_546 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_624[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_530 (Separable (None, 19, 19, 728)  536536      re_lu_546[0][0]
# __________________________________________________________________________________________________
# batch_normalization_625 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_530[0][0]
# __________________________________________________________________________________________________
# add_187 (Add)                   (None, 19, 19, 728)  0           batch_normalization_625[0][0]
#                                                                  add_186[0][0]
# __________________________________________________________________________________________________
# re_lu_547 (ReLU)                (None, 19, 19, 728)  0           add_187[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_531 (Separable (None, 19, 19, 728)  536536      re_lu_547[0][0]
# __________________________________________________________________________________________________
# batch_normalization_626 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_531[0][0]
# __________________________________________________________________________________________________
# re_lu_548 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_626[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_532 (Separable (None, 19, 19, 728)  536536      re_lu_548[0][0]
# __________________________________________________________________________________________________
# batch_normalization_627 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_532[0][0]
# __________________________________________________________________________________________________
# re_lu_549 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_627[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_533 (Separable (None, 19, 19, 728)  536536      re_lu_549[0][0]
# __________________________________________________________________________________________________
# batch_normalization_628 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_533[0][0]
# __________________________________________________________________________________________________
# add_188 (Add)                   (None, 19, 19, 728)  0           batch_normalization_628[0][0]
#                                                                  add_187[0][0]
# __________________________________________________________________________________________________
# re_lu_550 (ReLU)                (None, 19, 19, 728)  0           add_188[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_534 (Separable (None, 19, 19, 728)  536536      re_lu_550[0][0]
# __________________________________________________________________________________________________
# batch_normalization_629 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_534[0][0]
# __________________________________________________________________________________________________
# re_lu_551 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_629[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_535 (Separable (None, 19, 19, 728)  536536      re_lu_551[0][0]
# __________________________________________________________________________________________________
# batch_normalization_630 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_535[0][0]
# __________________________________________________________________________________________________
# re_lu_552 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_630[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_536 (Separable (None, 19, 19, 728)  536536      re_lu_552[0][0]
# __________________________________________________________________________________________________
# batch_normalization_631 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_536[0][0]
# __________________________________________________________________________________________________
# add_189 (Add)                   (None, 19, 19, 728)  0           batch_normalization_631[0][0]
#                                                                  add_188[0][0]
# __________________________________________________________________________________________________
# re_lu_553 (ReLU)                (None, 19, 19, 728)  0           add_189[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_537 (Separable (None, 19, 19, 728)  536536      re_lu_553[0][0]
# __________________________________________________________________________________________________
# batch_normalization_632 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_537[0][0]
# __________________________________________________________________________________________________
# re_lu_554 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_632[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_538 (Separable (None, 19, 19, 728)  536536      re_lu_554[0][0]
# __________________________________________________________________________________________________
# batch_normalization_633 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_538[0][0]
# __________________________________________________________________________________________________
# re_lu_555 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_633[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_539 (Separable (None, 19, 19, 728)  536536      re_lu_555[0][0]
# __________________________________________________________________________________________________
# batch_normalization_634 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_539[0][0]
# __________________________________________________________________________________________________
# add_190 (Add)                   (None, 19, 19, 728)  0           batch_normalization_634[0][0]
#                                                                  add_189[0][0]
# __________________________________________________________________________________________________
# re_lu_556 (ReLU)                (None, 19, 19, 728)  0           add_190[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_540 (Separable (None, 19, 19, 728)  536536      re_lu_556[0][0]
# __________________________________________________________________________________________________
# batch_normalization_635 (BatchN (None, 19, 19, 728)  2912        separable_conv2d_540[0][0]
# __________________________________________________________________________________________________
# re_lu_557 (ReLU)                (None, 19, 19, 728)  0           batch_normalization_635[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_541 (Separable (None, 19, 19, 1024) 752024      re_lu_557[0][0]
# __________________________________________________________________________________________________
# batch_normalization_636 (BatchN (None, 19, 19, 1024) 4096        separable_conv2d_541[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 10, 10, 1024) 745472      add_190[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_63 (MaxPooling2D) (None, 10, 10, 1024) 0           batch_normalization_636[0][0]
# __________________________________________________________________________________________________
# batch_normalization_637 (BatchN (None, 10, 10, 1024) 4096        conv2d_95[0][0]
# __________________________________________________________________________________________________
# add_191 (Add)                   (None, 10, 10, 1024) 0           max_pooling2d_63[0][0]
#                                                                  batch_normalization_637[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_542 (Separable (None, 10, 10, 1536) 1582080     add_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_638 (BatchN (None, 10, 10, 1536) 6144        separable_conv2d_542[0][0]
# __________________________________________________________________________________________________
# re_lu_558 (ReLU)                (None, 10, 10, 1536) 0           batch_normalization_638[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_543 (Separable (None, 10, 10, 2048) 3159552     re_lu_558[0][0]
# __________________________________________________________________________________________________
# batch_normalization_639 (BatchN (None, 10, 10, 2048) 8192        separable_conv2d_543[0][0]
# __________________________________________________________________________________________________
# re_lu_559 (ReLU)                (None, 10, 10, 2048) 0           batch_normalization_639[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_14 (Gl (None, 2048)         0           re_lu_559[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 1)            2049        global_average_pooling2d_14[0][0]
# ==================================================================================================
# Total params: 20,863,529
# Trainable params: 20,809,001
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)
